# %%
from pgmpy.factors.discrete import TabularCPD
from pgmpy.models import BayesianNetwork

# Establishing the structure
model = BayesianNetwork([
    ('Sensors', 'Data'),
    ('Sensors', 'Battery'),
    ('Data', 'Safety'),
    ('Data', 'Quality'),
    ('Quality', 'Precision'),
    ('Safety', 'Precision'),
    ('Precision', 'Utility'),
])

# Defining the relationships
Sensors_cpd = TabularCPD(
    variable='Sensors',
    variable_card=2,
    values=[[.75], [.25]]
)

Data_cpd = TabularCPD(
    variable='Data',
    variable_card=2,
    values=[[.8, .9], [.2, .1]],
    evidence=['Sensors'],
    evidence_card=[2]
)

Battery_cpd = TabularCPD(
    variable='Battery',
    variable_card=2,
    values=[[.8, .9], [.2, .1]],
    evidence=['Sensors'],
    evidence_card=[2]
)

Safety_cpd = TabularCPD(
    variable='Safety',
    variable_card=2,
    values=[[.6, .3], [.4, .7]],
    evidence=['Data'],
    evidence_card=[2]
)

Quality_cpd = TabularCPD(
    variable='Quality',
    variable_card=2,
    values=[[.6, .3], [.4, .7]],
    evidence=['Data'],
    evidence_card=[2]
)

Precision_cpd = TabularCPD(
    variable='Precision',
    variable_card=2,
    values=[[.9, .4, .2, .3], [.1, .6, .8, .7]],
    evidence=['Safety', 'Quality'],
    evidence_card=[2, 2]
)

Utility_cpd = TabularCPD(
    variable='Utility',
    variable_card=2,
    values=[[.6, .3], [.4, .7]],
    evidence=['Precision'],
    evidence_card=[2]
)

# Adding the relationships to the model
model.add_cpds(Sensors_cpd, Data_cpd, Battery_cpd, Safety_cpd, Quality_cpd, Precision_cpd, Utility_cpd)

# Verifying the structure of the model
model.get_cpds()
# Out:
# [<TabularCPD representing P(Sensors:2) at 0x15da968a950>,
#  <TabularCPD representing P(Data:2 | Sensors:2) at 0x15da9678d10>,
#  <TabularCPD representing P(Battery:2 | Sensors:2) at 0x15da9667010>,
#  <TabularCPD representing P(Safety:2 | Data:2) at 0x15da9667150>,
#  <TabularCPD representing P(Quality:2 | Data:2) at 0x15da9666a10>,
#  <TabularCPD representing P(Precision:2 | Safety:2, Quality:2) at 0x15da96ef290>,
#  <TabularCPD representing P(Utility:2 | Precision:2) at 0x15da96ef490>]

# %%
# Find the node paths to determine what provides information about a node
print(model.active_trail_nodes('Precision'))
print()

print(model.active_trail_nodes('Safety'))
print()

print(model.active_trail_nodes('Data'))
# Out:
# {'Precision': {'Utility', 'Quality', 'Safety', 'Data', 'Battery', 'Sensors', 'Precision'}}
#
# {'Safety': {'Utility', 'Quality', 'Safety', 'Data', 'Battery', 'Sensors', 'Precision'}}
#
# {'Data': {'Utility', 'Quality', 'Safety', 'Data', 'Battery', 'Sensors', 'Precision'}}

# %%
# Determination of local independencies
print(model.local_independencies('Sensors'))
print()

print(model.local_independencies('Quality'))
print()

print(model.local_independencies('Safety'))
print()

model.get_independencies()
# Out:
# (Quality ⟂ Battery, Sensors, Safety | Data)
#
# (Safety ⟂ Battery, Sensors, Quality | Data)
# (Utility ⟂ Battery, Sensors | Data)
# (Utility ⟂ Battery | Sensors)
# (Utility ⟂ Quality, Safety, Data, Battery, Sensors | Precision)
# (Utility ⟂ Battery, Sensors, Data | Quality, Safety)
# (Utility ⟂ Battery, Sensors | Quality, Data)
# (Utility ⟂ Battery | Sensors, Quality)
# (Utility ⟂ Battery, Sensors, Safety, Data | Quality, Precision)
# (Utility ⟂ Battery, Sensors | Safety, Data)
# (Utility ⟂ Battery | Sensors, Safety)
# (Utility ⟂ Battery, Sensors, Quality, Data | Safety, Precision)
# (Utility ⟂ Sensors | Battery, Data)
# (Utility ⟂ Battery | Sensors, Data)
# (Utility ⟂ Safety, Battery, Sensors, Quality | Precision, Data)
# (Utility ⟂ Safety, Sensors, Quality, Data | Battery, Precision)
# (Utility ⟂ Battery, Quality, Safety, Data | Sensors, Precision)
# (Utility ⟂ Battery, Sensors | Quality, Safety, Data)
# (Utility ⟂ Sensors, Data | Battery, Quality, Safety)
# (Utility ⟂ Battery, Data | Sensors, Quality, Safety)
# (Utility ⟂ Battery, Sensors, Data | Quality, Safety, Precision)
# (Utility ⟂ Sensors | Battery, Quality, Data)
# (Utility ⟂ Battery | Sensors, Quality, Data)
# (Utility ⟂ Battery, Sensors, Safety | Precision, Quality, Data)
# (Utility ⟂ Sensors, Safety, Data | Battery, Quality, Precision)
# (Utility ⟂ Battery, Safety, Data | Sensors, Quality, Precision)
# (Utility ⟂ Sensors | Battery, Safety, Data)
# (Utility ⟂ Battery | Sensors, Safety, Data)
# (Utility ⟂ Battery, Sensors, Quality | Precision, Safety, Data)
# (Utility ⟂ Sensors, Quality, Data | Battery, Safety, Precision)
# (Utility ⟂ Battery, Quality, Data | Sensors, Safety, Precision)
# (Utility ⟂ Safety, Sensors, Quality | Precision, Battery, Data)
# (Utility ⟂ Battery, Quality, Safety | Precision, Sensors, Data)
# (Utility ⟂ Quality, Safety, Data | Battery, Sensors, Precision)
# (Utility ⟂ Sensors | Battery, Quality, Safety, Data)
# (Utility ⟂ Battery | Sensors, Quality, Safety, Data)
# (Utility ⟂ Battery, Sensors | Precision, Quality, Safety, Data)
# (Utility ⟂ Data | Battery, Sensors, Quality, Safety)
# (Utility ⟂ Sensors, Data | Battery, Quality, Safety, Precision)
# (Utility ⟂ Battery, Data | Sensors, Quality, Safety, Precision)
# (Utility ⟂ Sensors, Safety | Precision, Battery, Quality, Data)
# (Utility ⟂ Battery, Safety | Precision, Sensors, Quality, Data)
# (Utility ⟂ Safety, Data | Battery, Sensors, Quality, Precision)
# (Utility ⟂ Sensors, Quality | Precision, Battery, Safety, Data)
# (Utility ⟂ Battery, Quality | Precision, Sensors, Safety, Data)
# (Utility ⟂ Quality, Data | Battery, Sensors, Safety, Precision)
# (Utility ⟂ Quality, Safety | Precision, Battery, Sensors, Data)
# (Utility ⟂ Sensors | Quality, Safety, Data, Battery, Precision)
# (Utility ⟂ Battery | Quality, Safety, Data, Sensors, Precision)
# (Utility ⟂ Data | Quality, Safety, Battery, Sensors, Precision)
# (Utility ⟂ Safety | Quality, Data, Battery, Sensors, Precision)
# (Utility ⟂ Quality | Safety, Data, Battery, Sensors, Precision)
# (Quality ⟂ Battery, Sensors, Safety | Data)
# (Quality ⟂ Battery | Sensors)
# (Quality ⟂ Utility | Precision)
# (Quality ⟂ Battery, Sensors | Utility, Data)
# (Quality ⟂ Battery | Utility, Sensors)
# (Quality ⟂ Battery, Sensors | Safety, Data)
# (Quality ⟂ Battery | Sensors, Safety)
# (Quality ⟂ Utility | Safety, Precision)
# (Quality ⟂ Sensors, Safety | Battery, Data)
# (Quality ⟂ Battery, Safety | Sensors, Data)
# (Quality ⟂ Battery, Utility, Sensors | Precision, Data)
# (Quality ⟂ Utility | Battery, Precision)
# (Quality ⟂ Battery, Utility | Sensors, Precision)
# (Quality ⟂ Battery, Sensors | Utility, Safety, Data)
# (Quality ⟂ Battery | Utility, Sensors, Safety)
# (Quality ⟂ Sensors | Battery, Utility, Data)
# (Quality ⟂ Battery | Utility, Sensors, Data)
# (Quality ⟂ Battery, Sensors | Precision, Utility, Data)
# (Quality ⟂ Battery | Utility, Sensors, Precision)
# (Quality ⟂ Sensors | Battery, Safety, Data)
# (Quality ⟂ Battery | Sensors, Safety, Data)
# (Quality ⟂ Battery, Utility, Sensors | Precision, Safety, Data)
# (Quality ⟂ Utility | Battery, Safety, Precision)
# (Quality ⟂ Battery, Utility | Sensors, Safety, Precision)
# (Quality ⟂ Safety | Battery, Sensors, Data)
# (Quality ⟂ Utility, Sensors | Precision, Battery, Data)
# (Quality ⟂ Battery, Utility | Precision, Sensors, Data)
# (Quality ⟂ Utility | Battery, Sensors, Precision)
# (Quality ⟂ Sensors | Battery, Utility, Safety, Data)
# (Quality ⟂ Battery | Utility, Sensors, Safety, Data)
# (Quality ⟂ Battery, Sensors | Precision, Utility, Safety, Data)
# (Quality ⟂ Battery | Utility, Sensors, Safety, Precision)
# (Quality ⟂ Sensors | Precision, Battery, Utility, Data)
# (Quality ⟂ Battery | Precision, Utility, Sensors, Data)
# (Quality ⟂ Utility, Sensors | Precision, Battery, Safety, Data)
# (Quality ⟂ Battery, Utility | Precision, Sensors, Safety, Data)
# (Quality ⟂ Utility | Battery, Sensors, Safety, Precision)
# (Quality ⟂ Utility | Precision, Battery, Sensors, Data)
# (Quality ⟂ Sensors | Safety, Data, Battery, Utility, Precision)
# (Quality ⟂ Battery | Safety, Data, Utility, Sensors, Precision)
# (Quality ⟂ Utility | Safety, Data, Battery, Sensors, Precision)
# (Safety ⟂ Battery, Sensors, Quality | Data)
# (Safety ⟂ Battery | Sensors)
# (Safety ⟂ Utility | Precision)
# (Safety ⟂ Battery, Sensors | Utility, Data)
# (Safety ⟂ Battery | Utility, Sensors)
# (Safety ⟂ Battery, Sensors | Quality, Data)
# (Safety ⟂ Battery | Sensors, Quality)
# (Safety ⟂ Utility | Quality, Precision)
# (Safety ⟂ Sensors, Quality | Battery, Data)
# (Safety ⟂ Battery, Quality | Sensors, Data)
# (Safety ⟂ Battery, Utility, Sensors | Precision, Data)
# (Safety ⟂ Utility | Battery, Precision)
# (Safety ⟂ Battery, Utility | Sensors, Precision)
# (Safety ⟂ Battery, Sensors | Utility, Quality, Data)
# (Safety ⟂ Battery | Sensors, Utility, Quality)
# (Safety ⟂ Sensors | Battery, Utility, Data)
# (Safety ⟂ Battery | Utility, Sensors, Data)
# (Safety ⟂ Battery, Sensors | Precision, Utility, Data)
# (Safety ⟂ Battery | Utility, Sensors, Precision)
# (Safety ⟂ Sensors | Battery, Quality, Data)
# (Safety ⟂ Battery | Sensors, Quality, Data)
# (Safety ⟂ Battery, Utility, Sensors | Precision, Quality, Data)
# (Safety ⟂ Utility | Battery, Quality, Precision)
# (Safety ⟂ Battery, Utility | Sensors, Quality, Precision)
# (Safety ⟂ Quality | Battery, Sensors, Data)
# (Safety ⟂ Utility, Sensors | Precision, Battery, Data)
# (Safety ⟂ Battery, Utility | Precision, Sensors, Data)
# (Safety ⟂ Utility | Battery, Sensors, Precision)
# (Safety ⟂ Sensors | Battery, Utility, Quality, Data)
# (Safety ⟂ Battery | Sensors, Utility, Quality, Data)
# (Safety ⟂ Battery, Sensors | Precision, Utility, Quality, Data)
# (Safety ⟂ Battery | Sensors, Utility, Quality, Precision)
# (Safety ⟂ Sensors | Precision, Battery, Utility, Data)
# (Safety ⟂ Battery | Precision, Utility, Sensors, Data)
# (Safety ⟂ Utility, Sensors | Precision, Battery, Quality, Data)
# (Safety ⟂ Battery, Utility | Precision, Sensors, Quality, Data)
# (Safety ⟂ Utility | Battery, Sensors, Quality, Precision)
# (Safety ⟂ Utility | Precision, Battery, Sensors, Data)
# (Safety ⟂ Sensors | Quality, Data, Battery, Utility, Precision)
# (Safety ⟂ Battery | Quality, Data, Utility, Sensors, Precision)
# (Safety ⟂ Utility | Quality, Data, Battery, Sensors, Precision)
# (Data ⟂ Battery | Sensors)
# (Data ⟂ Utility | Precision)
# (Data ⟂ Battery | Utility, Sensors)
# (Data ⟂ Utility, Precision | Quality, Safety)
# (Data ⟂ Battery | Sensors, Quality)
# (Data ⟂ Utility | Quality, Precision)
# (Data ⟂ Battery | Sensors, Safety)
# (Data ⟂ Utility | Safety, Precision)
# (Data ⟂ Utility | Battery, Precision)
# (Data ⟂ Battery, Utility | Sensors, Precision)
# (Data ⟂ Precision | Utility, Quality, Safety)
# (Data ⟂ Battery | Sensors, Utility, Quality)
# (Data ⟂ Battery | Utility, Sensors, Safety)
# (Data ⟂ Battery | Utility, Sensors, Precision)
# (Data ⟂ Utility, Precision | Battery, Quality, Safety)
# (Data ⟂ Battery, Utility, Precision | Sensors, Quality, Safety)
# (Data ⟂ Utility | Quality, Safety, Precision)
# (Data ⟂ Utility | Battery, Quality, Precision)
# (Data ⟂ Battery, Utility | Sensors, Quality, Precision)
# (Data ⟂ Utility | Battery, Safety, Precision)
# (Data ⟂ Battery, Utility | Sensors, Safety, Precision)
# (Data ⟂ Utility | Battery, Sensors, Precision)
# (Data ⟂ Precision | Battery, Utility, Quality, Safety)
# (Data ⟂ Battery, Precision | Sensors, Utility, Quality, Safety)
# (Data ⟂ Battery | Sensors, Utility, Quality, Precision)
# (Data ⟂ Battery | Utility, Sensors, Safety, Precision)
# (Data ⟂ Utility, Precision | Battery, Sensors, Quality, Safety)
# (Data ⟂ Utility | Battery, Quality, Safety, Precision)
# (Data ⟂ Battery, Utility | Sensors, Quality, Safety, Precision)
# (Data ⟂ Utility | Battery, Sensors, Quality, Precision)
# (Data ⟂ Utility | Battery, Sensors, Safety, Precision)
# (Data ⟂ Precision | Quality, Safety, Battery, Utility, Sensors)
# (Data ⟂ Battery | Quality, Safety, Utility, Sensors, Precision)
# (Data ⟂ Utility | Quality, Safety, Battery, Sensors, Precision)
# (Battery ⟂ Utility, Quality, Safety, Precision | Data)
# (Battery ⟂ Utility, Quality, Safety, Data, Precision | Sensors)
# (Battery ⟂ Utility | Precision)
# (Battery ⟂ Quality, Safety, Precision | Utility, Data)
# (Battery ⟂ Data, Quality, Safety, Precision | Utility, Sensors)
# (Battery ⟂ Utility, Precision | Quality, Safety)
# (Battery ⟂ Utility, Safety, Precision | Quality, Data)
# (Battery ⟂ Utility, Data, Safety, Precision | Sensors, Quality)
# (Battery ⟂ Utility | Quality, Precision)
# (Battery ⟂ Utility, Quality, Precision | Safety, Data)
# (Battery ⟂ Utility, Data, Quality, Precision | Sensors, Safety)
# (Battery ⟂ Utility | Safety, Precision)
# (Battery ⟂ Utility, Quality, Safety, Precision | Sensors, Data)
# (Battery ⟂ Utility, Quality, Safety | Precision, Data)
# (Battery ⟂ Utility, Quality, Safety, Data | Sensors, Precision)
# (Battery ⟂ Precision | Utility, Quality, Safety)
# (Battery ⟂ Safety, Precision | Utility, Quality, Data)
# (Battery ⟂ Data, Safety, Precision | Sensors, Utility, Quality)
# (Battery ⟂ Quality, Precision | Utility, Safety, Data)
# (Battery ⟂ Data, Quality, Precision | Utility, Sensors, Safety)
# (Battery ⟂ Quality, Safety, Precision | Utility, Sensors, Data)
# (Battery ⟂ Quality, Safety | Precision, Utility, Data)
# (Battery ⟂ Quality, Safety, Data | Utility, Sensors, Precision)
# (Battery ⟂ Utility, Precision | Quality, Safety, Data)
# (Battery ⟂ Utility, Data, Precision | Sensors, Quality, Safety)
# (Battery ⟂ Utility | Quality, Safety, Precision)
# (Battery ⟂ Utility, Safety, Precision | Sensors, Quality, Data)
# (Battery ⟂ Utility, Safety | Precision, Quality, Data)
# (Battery ⟂ Utility, Safety, Data | Sensors, Quality, Precision)
# (Battery ⟂ Utility, Quality, Precision | Sensors, Safety, Data)
# (Battery ⟂ Utility, Quality | Precision, Safety, Data)
# (Battery ⟂ Utility, Quality, Data | Sensors, Safety, Precision)
# (Battery ⟂ Utility, Quality, Safety | Precision, Sensors, Data)
# (Battery ⟂ Precision | Utility, Quality, Safety, Data)
# (Battery ⟂ Data, Precision | Sensors, Utility, Quality, Safety)
# (Battery ⟂ Safety, Precision | Sensors, Utility, Quality, Data)
# (Battery ⟂ Safety | Precision, Utility, Quality, Data)
# (Battery ⟂ Safety, Data | Sensors, Utility, Quality, Precision)
# (Battery ⟂ Quality, Precision | Utility, Sensors, Safety, Data)
# (Battery ⟂ Quality | Precision, Utility, Safety, Data)
# (Battery ⟂ Quality, Data | Utility, Sensors, Safety, Precision)
# (Battery ⟂ Quality, Safety | Precision, Utility, Sensors, Data)
# (Battery ⟂ Utility, Precision | Sensors, Quality, Safety, Data)
# (Battery ⟂ Utility | Precision, Quality, Safety, Data)
# (Battery ⟂ Utility, Data | Sensors, Quality, Safety, Precision)
# (Battery ⟂ Utility, Safety | Precision, Sensors, Quality, Data)
# (Battery ⟂ Utility, Quality | Precision, Sensors, Safety, Data)
# (Battery ⟂ Precision | Quality, Safety, Data, Utility, Sensors)
# (Battery ⟂ Data | Quality, Safety, Utility, Sensors, Precision)
# (Battery ⟂ Safety | Quality, Data, Utility, Sensors, Precision)
# (Battery ⟂ Quality | Safety, Data, Utility, Sensors, Precision)
# (Battery ⟂ Utility | Quality, Safety, Data, Sensors, Precision)
# (Sensors ⟂ Utility, Quality, Safety, Precision | Data)
# (Sensors ⟂ Utility | Precision)
# (Sensors ⟂ Quality, Safety, Precision | Utility, Data)
# (Sensors ⟂ Utility, Precision | Quality, Safety)
# (Sensors ⟂ Utility, Safety, Precision | Quality, Data)
# (Sensors ⟂ Utility | Quality, Precision)
# (Sensors ⟂ Utility, Quality, Precision | Safety, Data)
# (Sensors ⟂ Utility | Safety, Precision)
# (Sensors ⟂ Utility, Quality, Safety, Precision | Battery, Data)
# (Sensors ⟂ Utility, Quality, Safety | Precision, Data)
# (Sensors ⟂ Utility | Battery, Precision)
# (Sensors ⟂ Precision | Utility, Quality, Safety)
# (Sensors ⟂ Safety, Precision | Utility, Quality, Data)
# (Sensors ⟂ Quality, Precision | Utility, Safety, Data)
# (Sensors ⟂ Quality, Safety, Precision | Battery, Utility, Data)
# (Sensors ⟂ Quality, Safety | Precision, Utility, Data)
# (Sensors ⟂ Utility, Precision | Quality, Safety, Data)
# (Sensors ⟂ Utility, Precision | Battery, Quality, Safety)
# (Sensors ⟂ Utility | Quality, Safety, Precision)
# (Sensors ⟂ Utility, Safety, Precision | Battery, Quality, Data)
# (Sensors ⟂ Utility, Safety | Precision, Quality, Data)
# (Sensors ⟂ Utility | Battery, Quality, Precision)
# (Sensors ⟂ Utility, Quality, Precision | Battery, Safety, Data)
# (Sensors ⟂ Utility, Quality | Precision, Safety, Data)
# (Sensors ⟂ Utility | Battery, Safety, Precision)
# (Sensors ⟂ Utility, Quality, Safety | Precision, Battery, Data)
# (Sensors ⟂ Precision | Utility, Quality, Safety, Data)
# (Sensors ⟂ Precision | Battery, Utility, Quality, Safety)
# (Sensors ⟂ Safety, Precision | Battery, Utility, Quality, Data)
# (Sensors ⟂ Safety | Precision, Utility, Quality, Data)
# (Sensors ⟂ Quality, Precision | Battery, Utility, Safety, Data)
# (Sensors ⟂ Quality | Precision, Utility, Safety, Data)
# (Sensors ⟂ Quality, Safety | Precision, Battery, Utility, Data)
# (Sensors ⟂ Utility, Precision | Battery, Quality, Safety, Data)
# (Sensors ⟂ Utility | Precision, Quality, Safety, Data)
# (Sensors ⟂ Utility | Battery, Quality, Safety, Precision)
# (Sensors ⟂ Utility, Safety | Precision, Battery, Quality, Data)
# (Sensors ⟂ Utility, Quality | Precision, Battery, Safety, Data)
# (Sensors ⟂ Precision | Quality, Safety, Data, Battery, Utility)
# (Sensors ⟂ Safety | Quality, Data, Battery, Utility, Precision)
# (Sensors ⟂ Quality | Safety, Data, Battery, Utility, Precision)
# (Sensors ⟂ Utility | Quality, Safety, Data, Battery, Precision)
# (Precision ⟂ Battery, Sensors | Data)
# (Precision ⟂ Battery | Sensors)
# (Precision ⟂ Battery, Sensors | Utility, Data)
# (Precision ⟂ Battery | Utility, Sensors)
# (Precision ⟂ Battery, Sensors, Data | Quality, Safety)
# (Precision ⟂ Battery, Sensors | Quality, Data)
# (Precision ⟂ Battery | Sensors, Quality)
# (Precision ⟂ Battery, Sensors | Safety, Data)
# (Precision ⟂ Battery | Sensors, Safety)
# (Precision ⟂ Sensors | Battery, Data)
# (Precision ⟂ Battery | Sensors, Data)
# (Precision ⟂ Battery, Sensors, Data | Utility, Quality, Safety)
# (Precision ⟂ Battery, Sensors | Utility, Quality, Data)
# (Precision ⟂ Battery | Sensors, Utility, Quality)
# (Precision ⟂ Battery, Sensors | Utility, Safety, Data)
# (Precision ⟂ Battery | Utility, Sensors, Safety)
# (Precision ⟂ Sensors | Battery, Utility, Data)
# (Precision ⟂ Battery | Utility, Sensors, Data)
# (Precision ⟂ Battery, Sensors | Quality, Safety, Data)
# (Precision ⟂ Sensors, Data | Battery, Quality, Safety)
# (Precision ⟂ Battery, Data | Sensors, Quality, Safety)
# (Precision ⟂ Sensors | Battery, Quality, Data)
# (Precision ⟂ Battery | Sensors, Quality, Data)
# (Precision ⟂ Sensors | Battery, Safety, Data)
# (Precision ⟂ Battery | Sensors, Safety, Data)
# (Precision ⟂ Battery, Sensors | Utility, Quality, Safety, Data)
# (Precision ⟂ Sensors, Data | Battery, Utility, Quality, Safety)
# (Precision ⟂ Battery, Data | Sensors, Utility, Quality, Safety)
# (Precision ⟂ Sensors | Battery, Utility, Quality, Data)
# (Precision ⟂ Battery | Sensors, Utility, Quality, Data)
# (Precision ⟂ Sensors | Battery, Utility, Safety, Data)
# (Precision ⟂ Battery | Utility, Sensors, Safety, Data)
# (Precision ⟂ Sensors | Battery, Quality, Safety, Data)
# (Precision ⟂ Battery | Sensors, Quality, Safety, Data)
# (Precision ⟂ Data | Battery, Sensors, Quality, Safety)
# (Precision ⟂ Sensors | Quality, Safety, Data, Battery, Utility)
# (Precision ⟂ Battery | Quality, Safety, Data, Utility, Sensors)
# (Precision ⟂ Data | Quality, Safety, Battery, Utility, Sensors)

# %%
from pgmpy.inference import VariableElimination
# Calculate existing probabilities to verify everything is correct
inference = VariableElimination(model)
prob_sensors = inference.query(variables=['Sensors'])
print(prob_sensors)
# Out:
# +------------+----------------+
# | Sensors    |   phi(Sensors) |
# +============+================+
# | Sensors(0) |         0.7500 |
# +------------+----------------+
# | Sensors(1) |         0.2500 |
# +------------+----------------+

# %%
# Perform another probability calculation
prob_data = inference.query(variables=['Data'])
print(prob_data)
# Out:
# +---------+-------------+
# | Data    |   phi(Data) |
# +=========+=============+
# | Data(0) |      0.8250 |
# +---------+-------------+
# | Data(1) |      0.1750 |
# +---------+-------------+

# %%
# conditional probability
# The probability of achieving good data precision when data safety is ensured 
proba_precision_safety = inference.query(variables=['Precision'], evidence={'Safety': 1}) 
print(proba_precision_safety)
# Out:
# +--------------+------------------+
# | Precision    |   phi(Precision) |
# +==============+==================+
# | Precision(0) |           0.2481 |
# +--------------+------------------+
# | Precision(1) |           0.7519 |
# +--------------+------------------+

# %%
# Probability of achieving good precision when safety is lacking but quality is good
proba_precision_safety_quality = inference.query(variables=['Precision'], evidence={'Safety': 0, 'Quality': 1})
print(proba_precision_safety_quality)
# Out:
# +--------------+------------------+
# | Precision    |   phi(Precision) |
# +==============+==================+
# | Precision(0) |           0.4000 |
# +--------------+------------------+
# | Precision(1) |           0.6000 |
# +--------------+------------------+
