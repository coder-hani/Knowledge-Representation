# %%
from pgmpy.factors.discrete import TabularCPD
from pgmpy.models import BayesianNetwork

# Establishing the structure
model = BayesianNetwork([
    ('Demand', 'Allocation'),
    ('State', 'Allocation'),
    ('Allocation', 'Performance'),
    ('Demand', 'Type'),
    ('Type', 'Volume'),
    ('Performance', 'Need'),
    ('Performance', 'Satisfaction'),
])

# Defining the relationships
Demand_cpd = TabularCPD(
    variable='Demand',
    variable_card=2,
    values=[[.6], [.4]]
)

State_cpd = TabularCPD(
    variable='State',
    variable_card=2,
    values=[[.6], [.4]]
)

Allocation_cpd = TabularCPD(
    variable='Allocation',
    variable_card=2,
    values=[[.7, .8, .95, .8], [.3, .2, .05, .2]],
    evidence=['Demand', 'State'],
    evidence_card=[2, 2]
)

Performance_cpd = TabularCPD(
    variable='Performance',
    variable_card=2,
    values=[[.2, .1], [.8, .9]],
    evidence=['Allocation'],
    evidence_card=[2]
)

Type_cpd = TabularCPD(
    variable='Type',
    variable_card=2,
    values=[[.8, .9], [.2, .1]],
    evidence=['Demand'],
    evidence_card=[2]
)

Volume_cpd = TabularCPD(
    variable='Volume',
    variable_card=2,
    values=[[.9, .95], [.1, .05]],
    evidence=['Type'],
    evidence_card=[2]
)

Satisfaction_cpd = TabularCPD(
    variable='Satisfaction',
    variable_card=2,
    values=[[.9, .95], [.1, .05]],
    evidence=['Performance'],
    evidence_card=[2]
)

Need_cpd = TabularCPD(
    variable='Need',
    variable_card=2,
    values=[[.9, .95], [.1, .05]],
    evidence=['Performance'],
    evidence_card=[2]
)

# Adding the relationships to the model
model.add_cpds(Demand_cpd, State_cpd, Allocation_cpd, Performance_cpd, Satisfaction_cpd, Need_cpd, Type_cpd, Volume_cpd)

# Verifying the structure of the model
model.get_cpds()
# Out:
# [<TabularCPD representing P(Demand:2) at 0x135c7634210>,
#  <TabularCPD representing P(State:2) at 0x135c76ecf50>,
#  <TabularCPD representing P(Allocation:2 | Demand:2, State:2) at 0x135c76ecc90>,
#  <TabularCPD representing P(Performance:2 | Allocation:2) at 0x135c76ece90>,
#  <TabularCPD representing P(Satisfaction:2 | Performance:2) at 0x135c76ecc50>,
#  <TabularCPD representing P(Need:2 | Performance:2) at 0x135c76ed010>,
#  <TabularCPD representing P(Type:2 | Demand:2) at 0x135c76ec350>,
#  <TabularCPD representing P(Volume:2 | Type:2) at 0x135c76ed150>]

# %%
# Find the paths of the nodes to determine what provides information about a node
print(model.active_trail_nodes('Demand'))
print()

print(model.active_trail_nodes('Type'))
print()

print(model.active_trail_nodes('Satisfaction'))
# Out:
# {'Demand': {'Performance', 'Need', 'Type', 'Satisfaction', 'Volume', 'Demand', 'Allocation'}}
#
# {'Type': {'Performance', 'Need', 'Type', 'Satisfaction', 'Volume', 'Demand', 'Allocation'}}
#
# {'Satisfaction': {'Performance', 'Need', 'Type', 'Demand', 'State', 'Satisfaction', 'Volume', 'Allocation'}}

# %%
# Determination of local independencies
print(model.local_independencies('Demand'))
print()

print(model.local_independencies('Volume'))
print()

print(model.local_independencies('Performance'))
print()

model.get_independencies()
# Out:
# (Demand ⟂ State)
#
# (Volume ⟂ State, Performance, Need, Satisfaction, Demand, Allocation | Type)
#
# (Performance ⟂ Demand, Type, State, Volume | Allocation)
# (Performance ⟂ Volume | Type)
# (Performance ⟂ Type, Volume | Demand)
# (Performance ⟂ Demand, Type, State, Volume | Allocation)
# (Performance ⟂ Volume | State, Type)
# (Performance ⟂ Type, Volume | State, Demand)
# (Performance ⟂ Demand, Type, Volume | State, Allocation)
# (Performance ⟂ Volume | Need, Type)
# (Performance ⟂ Type, Volume | Demand, Need)
# (Performance ⟂ Demand, Type, State, Volume | Need, Allocation)
# (Performance ⟂ Volume | Satisfaction, Type)
# (Performance ⟂ Volume | Demand, Type)
# (Performance ⟂ Demand, State, Volume | Allocation, Type)
# (Performance ⟂ Type, Volume | Demand, Satisfaction)
# (Performance ⟂ Demand, Type, State, Volume | Allocation, Satisfaction)
# (Performance ⟂ Type | Demand, Volume)
# (Performance ⟂ Demand, Type, State | Allocation, Volume)
# (Performance ⟂ State, Type, Volume | Demand, Allocation)
# (Performance ⟂ Volume | State, Need, Type)
# (Performance ⟂ Type, Volume | State, Need, Demand)
# (Performance ⟂ Demand, Type, Volume | State, Need, Allocation)
# (Performance ⟂ Volume | State, Satisfaction, Type)
# (Performance ⟂ Volume | State, Type, Demand)
# (Performance ⟂ Demand, Volume | State, Allocation, Type)
# (Performance ⟂ Type, Volume | State, Satisfaction, Demand)
# (Performance ⟂ Demand, Type, Volume | State, Allocation, Satisfaction)
# (Performance ⟂ Type | State, Demand, Volume)
# (Performance ⟂ Demand, Type | State, Allocation, Volume)
# (Performance ⟂ Type, Volume | State, Allocation, Demand)
# (Performance ⟂ Volume | Need, Satisfaction, Type)
# (Performance ⟂ Volume | Demand, Need, Type)
# (Performance ⟂ State, Demand, Volume | Need, Type, Allocation)
# (Performance ⟂ Type, Volume | Demand, Need, Satisfaction)
# (Performance ⟂ State, Type, Demand, Volume | Need, Satisfaction, Allocation)
# (Performance ⟂ Type | Demand, Need, Volume)
# (Performance ⟂ State, Type, Demand | Need, Allocation, Volume)
# (Performance ⟂ State, Type, Volume | Demand, Need, Allocation)
# (Performance ⟂ Volume | Demand, Satisfaction, Type)
# (Performance ⟂ State, Demand, Volume | Allocation, Satisfaction, Type)
# (Performance ⟂ State, Demand | Allocation, Type, Volume)
# (Performance ⟂ State, Volume | Demand, Allocation, Type)
# (Performance ⟂ Type | Demand, Satisfaction, Volume)
# (Performance ⟂ State, Type, Demand | Allocation, Satisfaction, Volume)
# (Performance ⟂ State, Type, Volume | Demand, Allocation, Satisfaction)
# (Performance ⟂ State, Type | Demand, Allocation, Volume)
# (Performance ⟂ Volume | State, Need, Satisfaction, Type)
# (Performance ⟂ Volume | State, Need, Type, Demand)
# (Performance ⟂ Demand, Volume | State, Need, Type, Allocation)
# (Performance ⟂ Type, Volume | State, Need, Satisfaction, Demand)
# (Performance ⟂ Demand, Type, Volume | State, Need, Satisfaction, Allocation)
# (Performance ⟂ Type | State, Need, Demand, Volume)
# (Performance ⟂ Demand, Type | State, Need, Allocation, Volume)
# (Performance ⟂ Type, Volume | State, Allocation, Need, Demand)
# (Performance ⟂ Volume | State, Satisfaction, Type, Demand)
# (Performance ⟂ Demand, Volume | State, Allocation, Satisfaction, Type)
# (Performance ⟂ Demand | State, Allocation, Type, Volume)
# (Performance ⟂ Volume | State, Allocation, Type, Demand)
# (Performance ⟂ Type | State, Satisfaction, Demand, Volume)
# (Performance ⟂ Demand, Type | State, Allocation, Satisfaction, Volume)
# (Performance ⟂ Type, Volume | State, Allocation, Satisfaction, Demand)
# (Performance ⟂ Type | State, Allocation, Demand, Volume)
# (Performance ⟂ Volume | Demand, Need, Satisfaction, Type)
# (Performance ⟂ State, Demand, Volume | Need, Satisfaction, Type, Allocation)
# (Performance ⟂ State, Demand | Need, Type, Allocation, Volume)
# (Performance ⟂ State, Volume | Demand, Need, Type, Allocation)
# (Performance ⟂ Type | Demand, Need, Satisfaction, Volume)
# (Performance ⟂ State, Type, Demand | Need, Satisfaction, Allocation, Volume)
# (Performance ⟂ State, Type, Volume | Demand, Need, Satisfaction, Allocation)
# (Performance ⟂ State, Type | Demand, Need, Allocation, Volume)
# (Performance ⟂ State, Demand | Allocation, Satisfaction, Type, Volume)
# (Performance ⟂ State, Volume | Demand, Allocation, Satisfaction, Type)
# (Performance ⟂ State | Demand, Allocation, Type, Volume)
# (Performance ⟂ State, Type | Demand, Allocation, Satisfaction, Volume)
# (Performance ⟂ Volume | Need, Type, Demand, State, Satisfaction)
# (Performance ⟂ Demand, Volume | Need, Type, State, Satisfaction, Allocation)
# (Performance ⟂ Demand | Need, Type, State, Volume, Allocation)
# (Performance ⟂ Volume | Need, Type, Demand, State, Allocation)
# (Performance ⟂ Type | Need, Demand, State, Satisfaction, Volume)
# (Performance ⟂ Demand, Type | Need, State, Satisfaction, Volume, Allocation)
# (Performance ⟂ Type, Volume | Need, Demand, State, Satisfaction, Allocation)
# (Performance ⟂ Type | Need, Demand, State, Volume, Allocation)
# (Performance ⟂ Demand | Type, State, Satisfaction, Volume, Allocation)
# (Performance ⟂ Volume | Type, Demand, State, Satisfaction, Allocation)
# (Performance ⟂ Type | Demand, State, Satisfaction, Volume, Allocation)
# (Performance ⟂ State, Demand | Need, Type, Satisfaction, Volume, Allocation)
# (Performance ⟂ State, Volume | Need, Type, Demand, Satisfaction, Allocation)
# (Performance ⟂ State | Need, Type, Demand, Volume, Allocation)
# (Performance ⟂ State, Type | Need, Demand, Satisfaction, Volume, Allocation)
# (Performance ⟂ State | Type, Demand, Satisfaction, Volume, Allocation)
# (Performance ⟂ Demand | Need, Type, State, Satisfaction, Volume, Allocation)
# (Performance ⟂ Volume | Need, Type, Demand, State, Satisfaction, Allocation)
# (Performance ⟂ Type | Need, Demand, State, Satisfaction, Volume, Allocation)
# (Performance ⟂ State | Need, Type, Demand, Satisfaction, Volume, Allocation)
# (Need ⟂ State, Type, Satisfaction, Volume, Demand, Allocation | Performance)
# (Need ⟂ Volume | Type)
# (Need ⟂ Type, Volume | Demand)
# (Need ⟂ Demand, Type, State, Volume | Allocation)
# (Need ⟂ Type, Satisfaction, Volume, Demand, Allocation | State, Performance)
# (Need ⟂ Volume | State, Type)
# (Need ⟂ Type, Volume | State, Demand)
# (Need ⟂ Demand, Type, Volume | State, Allocation)
# (Need ⟂ State, Satisfaction, Volume, Demand, Allocation | Performance, Type)
# (Need ⟂ State, Type, Volume, Demand, Allocation | Performance, Satisfaction)
# (Need ⟂ State, Type, Satisfaction, Demand, Allocation | Performance, Volume)
# (Need ⟂ State, Type, Satisfaction, Volume, Allocation | Demand, Performance)
# (Need ⟂ State, Type, Satisfaction, Volume, Demand | Performance, Allocation)
# (Need ⟂ Volume | Satisfaction, Type)
# (Need ⟂ Volume | Demand, Type)
# (Need ⟂ Demand, State, Volume | Allocation, Type)
# (Need ⟂ Type, Volume | Demand, Satisfaction)
# (Need ⟂ Demand, Type, State, Volume | Allocation, Satisfaction)
# (Need ⟂ Type | Demand, Volume)
# (Need ⟂ Demand, Type, State | Allocation, Volume)
# (Need ⟂ State, Type, Volume | Demand, Allocation)
# (Need ⟂ Demand, Allocation, Satisfaction, Volume | State, Performance, Type)
# (Need ⟂ Demand, Allocation, Type, Volume | State, Performance, Satisfaction)
# (Need ⟂ Demand, Allocation, Satisfaction, Type | State, Performance, Volume)
# (Need ⟂ Volume, Allocation, Satisfaction, Type | State, Performance, Demand)
# (Need ⟂ Demand, Volume, Satisfaction, Type | State, Performance, Allocation)
# (Need ⟂ Volume | State, Satisfaction, Type)
# (Need ⟂ Volume | State, Type, Demand)
# (Need ⟂ Demand, Volume | State, Allocation, Type)
# (Need ⟂ Type, Volume | State, Satisfaction, Demand)
# (Need ⟂ Demand, Type, Volume | State, Allocation, Satisfaction)
# (Need ⟂ Type | State, Demand, Volume)
# (Need ⟂ Demand, Type | State, Allocation, Volume)
# (Need ⟂ Type, Volume | State, Allocation, Demand)
# (Need ⟂ State, Allocation, Demand, Volume | Performance, Satisfaction, Type)
# (Need ⟂ State, Allocation, Satisfaction, Demand | Performance, Type, Volume)
# (Need ⟂ State, Allocation, Satisfaction, Volume | Demand, Performance, Type)
# (Need ⟂ State, Satisfaction, Demand, Volume | Performance, Allocation, Type)
# (Need ⟂ State, Allocation, Type, Demand | Performance, Satisfaction, Volume)
# (Need ⟂ State, Allocation, Type, Volume | Demand, Performance, Satisfaction)
# (Need ⟂ State, Type, Demand, Volume | Performance, Allocation, Satisfaction)
# (Need ⟂ State, Allocation, Satisfaction, Type | Demand, Performance, Volume)
# (Need ⟂ State, Satisfaction, Demand, Type | Performance, Allocation, Volume)
# (Need ⟂ State, Volume, Satisfaction, Type | Demand, Performance, Allocation)
# (Need ⟂ Volume | Demand, Satisfaction, Type)
# (Need ⟂ State, Demand, Volume | Allocation, Satisfaction, Type)
# (Need ⟂ State, Demand | Allocation, Type, Volume)
# (Need ⟂ State, Volume | Demand, Allocation, Type)
# (Need ⟂ Type | Demand, Satisfaction, Volume)
# (Need ⟂ State, Type, Demand | Allocation, Satisfaction, Volume)
# (Need ⟂ State, Type, Volume | Demand, Allocation, Satisfaction)
# (Need ⟂ State, Type | Demand, Allocation, Volume)
# (Need ⟂ Demand, Allocation, Volume | State, Performance, Satisfaction, Type)
# (Need ⟂ Demand, Allocation, Satisfaction | State, Performance, Type, Volume)
# (Need ⟂ Allocation, Satisfaction, Volume | State, Performance, Type, Demand)
# (Need ⟂ Demand, Satisfaction, Volume | State, Performance, Allocation, Type)
# (Need ⟂ Demand, Allocation, Type | State, Performance, Satisfaction, Volume)
# (Need ⟂ Allocation, Type, Volume | State, Performance, Satisfaction, Demand)
# (Need ⟂ Demand, Type, Volume | State, Performance, Allocation, Satisfaction)
# (Need ⟂ Allocation, Satisfaction, Type | State, Performance, Demand, Volume)
# (Need ⟂ Demand, Satisfaction, Type | State, Performance, Allocation, Volume)
# (Need ⟂ Volume, Satisfaction, Type | State, Performance, Allocation, Demand)
# (Need ⟂ Volume | State, Satisfaction, Type, Demand)
# (Need ⟂ Demand, Volume | State, Allocation, Satisfaction, Type)
# (Need ⟂ Demand | State, Allocation, Type, Volume)
# (Need ⟂ Volume | State, Allocation, Type, Demand)
# (Need ⟂ Type | State, Satisfaction, Demand, Volume)
# (Need ⟂ Demand, Type | State, Allocation, Satisfaction, Volume)
# (Need ⟂ Type, Volume | State, Allocation, Satisfaction, Demand)
# (Need ⟂ Type | State, Allocation, Demand, Volume)
# (Need ⟂ State, Allocation, Demand | Performance, Satisfaction, Type, Volume)
# (Need ⟂ State, Allocation, Volume | Demand, Performance, Satisfaction, Type)
# (Need ⟂ State, Demand, Volume | Performance, Allocation, Satisfaction, Type)
# (Need ⟂ State, Allocation, Satisfaction | Demand, Performance, Type, Volume)
# (Need ⟂ State, Satisfaction, Demand | Performance, Allocation, Type, Volume)
# (Need ⟂ State, Satisfaction, Volume | Demand, Performance, Allocation, Type)
# (Need ⟂ State, Allocation, Type | Demand, Performance, Satisfaction, Volume)
# (Need ⟂ State, Type, Demand | Performance, Allocation, Satisfaction, Volume)
# (Need ⟂ State, Type, Volume | Demand, Performance, Allocation, Satisfaction)
# (Need ⟂ State, Satisfaction, Type | Demand, Performance, Allocation, Volume)
# (Need ⟂ State, Demand | Allocation, Satisfaction, Type, Volume)
# (Need ⟂ State, Volume | Demand, Allocation, Satisfaction, Type)
# (Need ⟂ State | Demand, Allocation, Type, Volume)
# (Need ⟂ State, Type | Demand, Allocation, Satisfaction, Volume)
# (Need ⟂ Demand, Allocation | Performance, Type, State, Satisfaction, Volume)
# (Need ⟂ Allocation, Volume | Performance, Type, Demand, State, Satisfaction)
# (Need ⟂ Demand, Volume | Performance, Type, State, Satisfaction, Allocation)
# (Need ⟂ Allocation, Satisfaction | Performance, Type, Demand, State, Volume)
# (Need ⟂ Demand, Satisfaction | Performance, Type, State, Volume, Allocation)
# (Need ⟂ Satisfaction, Volume | Performance, Type, Demand, State, Allocation)
# (Need ⟂ Allocation, Type | Performance, Demand, State, Satisfaction, Volume)
# (Need ⟂ Demand, Type | Performance, State, Satisfaction, Volume, Allocation)
# (Need ⟂ Type, Volume | Performance, Demand, State, Satisfaction, Allocation)
# (Need ⟂ Satisfaction, Type | Performance, Demand, State, Volume, Allocation)
# (Need ⟂ Demand | Type, State, Satisfaction, Volume, Allocation)
# (Need ⟂ Volume | Type, Demand, State, Satisfaction, Allocation)
# (Need ⟂ Type | Demand, State, Satisfaction, Volume, Allocation)
# (Need ⟂ State, Allocation | Performance, Type, Demand, Satisfaction, Volume)
# (Need ⟂ State, Demand | Performance, Type, Satisfaction, Volume, Allocation)
# (Need ⟂ State, Volume | Performance, Type, Demand, Satisfaction, Allocation)
# (Need ⟂ State, Satisfaction | Performance, Type, Demand, Volume, Allocation)
# (Need ⟂ State, Type | Performance, Demand, Satisfaction, Volume, Allocation)
# (Need ⟂ State | Type, Demand, Satisfaction, Volume, Allocation)
# (Need ⟂ Allocation | Performance, Type, Demand, State, Satisfaction, Volume)
# (Need ⟂ Demand | Performance, Type, State, Satisfaction, Volume, Allocation)
# (Need ⟂ Volume | Performance, Type, Demand, State, Satisfaction, Allocation)
# (Need ⟂ Satisfaction | Performance, Type, Demand, State, Volume, Allocation)
# (Need ⟂ Type | Performance, Demand, State, Satisfaction, Volume, Allocation)
# (Need ⟂ State | Performance, Type, Demand, Satisfaction, Volume, Allocation)
# (Type ⟂ State)
# (Type ⟂ Need, Satisfaction | Performance)
# (Type ⟂ State | Volume)
# (Type ⟂ State, Performance, Need, Satisfaction, Allocation | Demand)
# (Type ⟂ Performance, Need, Satisfaction | Allocation)
# (Type ⟂ Need, Satisfaction | State, Performance)
# (Type ⟂ Performance, Need, Satisfaction, Allocation | State, Demand)
# (Type ⟂ Performance, Need, Satisfaction | State, Allocation)
# (Type ⟂ Satisfaction | Performance, Need)
# (Type ⟂ Need | Performance, Satisfaction)
# (Type ⟂ Need, Satisfaction | Performance, Volume)
# (Type ⟂ State, Need, Satisfaction, Allocation | Demand, Performance)
# (Type ⟂ Need, Satisfaction | Performance, Allocation)
# (Type ⟂ State, Performance, Allocation, Satisfaction | Demand, Need)
# (Type ⟂ Performance, Satisfaction | Need, Allocation)
# (Type ⟂ State, Performance, Need, Allocation | Demand, Satisfaction)
# (Type ⟂ Performance, Need | Allocation, Satisfaction)
# (Type ⟂ State, Performance, Need, Satisfaction, Allocation | Demand, Volume)
# (Type ⟂ Performance, Need, Satisfaction | Allocation, Volume)
# (Type ⟂ State, Performance, Need, Satisfaction | Demand, Allocation)
# (Type ⟂ Satisfaction | State, Performance, Need)
# (Type ⟂ Need | State, Performance, Satisfaction)
# (Type ⟂ Need, Satisfaction | State, Performance, Volume)
# (Type ⟂ Need, Satisfaction, Allocation | State, Performance, Demand)
# (Type ⟂ Need, Satisfaction | State, Performance, Allocation)
# (Type ⟂ Performance, Allocation, Satisfaction | State, Need, Demand)
# (Type ⟂ Performance, Satisfaction | State, Need, Allocation)
# (Type ⟂ Performance, Need, Allocation | State, Satisfaction, Demand)
# (Type ⟂ Performance, Need | State, Allocation, Satisfaction)
# (Type ⟂ Performance, Need, Satisfaction, Allocation | State, Demand, Volume)
# (Type ⟂ Performance, Need, Satisfaction | State, Allocation, Volume)
# (Type ⟂ Performance, Need, Satisfaction | State, Allocation, Demand)
# (Type ⟂ Satisfaction | Performance, Need, Volume)
# (Type ⟂ State, Allocation, Satisfaction | Demand, Performance, Need)
# (Type ⟂ Satisfaction | Performance, Need, Allocation)
# (Type ⟂ Need | Performance, Satisfaction, Volume)
# (Type ⟂ State, Need, Allocation | Demand, Performance, Satisfaction)
# (Type ⟂ Need | Performance, Allocation, Satisfaction)
# (Type ⟂ State, Need, Satisfaction, Allocation | Demand, Performance, Volume)
# (Type ⟂ Need, Satisfaction | Performance, Allocation, Volume)
# (Type ⟂ State, Need, Satisfaction | Demand, Performance, Allocation)
# (Type ⟂ State, Performance, Allocation | Demand, Need, Satisfaction)
# (Type ⟂ Performance | Need, Satisfaction, Allocation)
# (Type ⟂ State, Performance, Allocation, Satisfaction | Demand, Need, Volume)
# (Type ⟂ Performance, Satisfaction | Need, Allocation, Volume)
# (Type ⟂ State, Performance, Satisfaction | Demand, Need, Allocation)
# (Type ⟂ State, Performance, Need, Allocation | Demand, Satisfaction, Volume)
# (Type ⟂ Performance, Need | Allocation, Satisfaction, Volume)
# (Type ⟂ State, Performance, Need | Demand, Allocation, Satisfaction)
# (Type ⟂ State, Performance, Need, Satisfaction | Demand, Allocation, Volume)
# (Type ⟂ Satisfaction | State, Performance, Need, Volume)
# (Type ⟂ Allocation, Satisfaction | State, Performance, Need, Demand)
# (Type ⟂ Satisfaction | State, Performance, Need, Allocation)
# (Type ⟂ Need | State, Performance, Satisfaction, Volume)
# (Type ⟂ Need, Allocation | State, Performance, Satisfaction, Demand)
# (Type ⟂ Need | State, Performance, Allocation, Satisfaction)
# (Type ⟂ Need, Satisfaction, Allocation | State, Performance, Demand, Volume)
# (Type ⟂ Need, Satisfaction | State, Performance, Allocation, Volume)
# (Type ⟂ Need, Satisfaction | State, Performance, Allocation, Demand)
# (Type ⟂ Performance, Allocation | State, Need, Satisfaction, Demand)
# (Type ⟂ Performance | State, Need, Satisfaction, Allocation)
# (Type ⟂ Performance, Allocation, Satisfaction | State, Need, Demand, Volume)
# (Type ⟂ Performance, Satisfaction | State, Need, Allocation, Volume)
# (Type ⟂ Performance, Satisfaction | State, Allocation, Need, Demand)
# (Type ⟂ Performance, Need, Allocation | State, Satisfaction, Demand, Volume)
# (Type ⟂ Performance, Need | State, Allocation, Satisfaction, Volume)
# (Type ⟂ Performance, Need | State, Allocation, Satisfaction, Demand)
# (Type ⟂ Performance, Need, Satisfaction | State, Allocation, Demand, Volume)
# (Type ⟂ State, Allocation | Demand, Performance, Need, Satisfaction)
# (Type ⟂ State, Allocation, Satisfaction | Demand, Performance, Need, Volume)
# (Type ⟂ Satisfaction | Performance, Need, Allocation, Volume)
# (Type ⟂ State, Satisfaction | Demand, Performance, Need, Allocation)
# (Type ⟂ State, Need, Allocation | Demand, Performance, Satisfaction, Volume)
# (Type ⟂ Need | Performance, Allocation, Satisfaction, Volume)
# (Type ⟂ State, Need | Demand, Performance, Allocation, Satisfaction)
# (Type ⟂ State, Need, Satisfaction | Demand, Performance, Allocation, Volume)
# (Type ⟂ State, Performance, Allocation | Demand, Need, Satisfaction, Volume)
# (Type ⟂ Performance | Need, Satisfaction, Allocation, Volume)
# (Type ⟂ State, Performance | Demand, Need, Satisfaction, Allocation)
# (Type ⟂ State, Performance, Satisfaction | Demand, Need, Allocation, Volume)
# (Type ⟂ State, Performance, Need | Demand, Allocation, Satisfaction, Volume)
# (Type ⟂ Allocation | Performance, Need, Demand, State, Satisfaction)
# (Type ⟂ Allocation, Satisfaction | Performance, Need, Demand, State, Volume)
# (Type ⟂ Satisfaction | Performance, Need, State, Volume, Allocation)
# (Type ⟂ Satisfaction | Performance, Need, Demand, State, Allocation)
# (Type ⟂ Need, Allocation | Performance, Demand, State, Satisfaction, Volume)
# (Type ⟂ Need | Performance, State, Satisfaction, Volume, Allocation)
# (Type ⟂ Need | Performance, Demand, State, Satisfaction, Allocation)
# (Type ⟂ Need, Satisfaction | Performance, Demand, State, Volume, Allocation)
# (Type ⟂ Performance, Allocation | Need, Demand, State, Satisfaction, Volume)
# (Type ⟂ Performance | Need, State, Satisfaction, Volume, Allocation)
# (Type ⟂ Performance | Need, Demand, State, Satisfaction, Allocation)
# (Type ⟂ Performance, Satisfaction | Need, Demand, State, Volume, Allocation)
# (Type ⟂ Performance, Need | Demand, State, Satisfaction, Volume, Allocation)
# (Type ⟂ State, Allocation | Performance, Need, Demand, Satisfaction, Volume)
# (Type ⟂ State | Performance, Need, Demand, Satisfaction, Allocation)
# (Type ⟂ State, Satisfaction | Performance, Need, Demand, Volume, Allocation)
# (Type ⟂ State, Need | Performance, Demand, Satisfaction, Volume, Allocation)
# (Type ⟂ State, Performance | Need, Demand, Satisfaction, Volume, Allocation)
# (Type ⟂ Allocation | Performance, Need, Demand, State, Satisfaction, Volume)
# (Type ⟂ Satisfaction | Performance, Need, Demand, State, Volume, Allocation)
# (Type ⟂ Need | Performance, Demand, State, Satisfaction, Volume, Allocation)
# (Type ⟂ Performance | Need, Demand, State, Satisfaction, Volume, Allocation)
# (Type ⟂ State | Performance, Need, Demand, Satisfaction, Volume, Allocation)
# (Demand ⟂ State)
# (Demand ⟂ Need, Satisfaction | Performance)
# (Demand ⟂ State, Volume | Type)
# (Demand ⟂ State | Volume)
# (Demand ⟂ Performance, Need, Satisfaction | Allocation)
# (Demand ⟂ Need, Satisfaction | State, Performance)
# (Demand ⟂ Volume | State, Type)
# (Demand ⟂ Performance, Need, Satisfaction | State, Allocation)
# (Demand ⟂ Satisfaction | Performance, Need)
# (Demand ⟂ Need, Satisfaction, Volume | Performance, Type)
# (Demand ⟂ Need | Performance, Satisfaction)
# (Demand ⟂ Need, Satisfaction | Performance, Volume)
# (Demand ⟂ Need, Satisfaction | Performance, Allocation)
# (Demand ⟂ Volume | Need, Type)
# (Demand ⟂ Performance, Satisfaction | Need, Allocation)
# (Demand ⟂ Volume | Satisfaction, Type)
# (Demand ⟂ State | Type, Volume)
# (Demand ⟂ Performance, Need, Satisfaction, Volume | Allocation, Type)
# (Demand ⟂ Performance, Need | Allocation, Satisfaction)
# (Demand ⟂ Performance, Need, Satisfaction | Allocation, Volume)
# (Demand ⟂ Satisfaction | State, Performance, Need)
# (Demand ⟂ Need, Satisfaction, Volume | State, Performance, Type)
# (Demand ⟂ Need | State, Performance, Satisfaction)
# (Demand ⟂ Need, Satisfaction | State, Performance, Volume)
# (Demand ⟂ Need, Satisfaction | State, Performance, Allocation)
# (Demand ⟂ Volume | State, Need, Type)
# (Demand ⟂ Performance, Satisfaction | State, Need, Allocation)
# (Demand ⟂ Volume | State, Satisfaction, Type)
# (Demand ⟂ Performance, Need, Satisfaction, Volume | State, Allocation, Type)
# (Demand ⟂ Performance, Need | State, Allocation, Satisfaction)
# (Demand ⟂ Performance, Need, Satisfaction | State, Allocation, Volume)
# (Demand ⟂ Satisfaction, Volume | Performance, Need, Type)
# (Demand ⟂ Satisfaction | Performance, Need, Volume)
# (Demand ⟂ Satisfaction | Performance, Need, Allocation)
# (Demand ⟂ Need, Volume | Performance, Satisfaction, Type)
# (Demand ⟂ Need, Satisfaction | Performance, Type, Volume)
# (Demand ⟂ Need, Satisfaction, Volume | Performance, Allocation, Type)
# (Demand ⟂ Need | Performance, Satisfaction, Volume)
# (Demand ⟂ Need | Performance, Allocation, Satisfaction)
# (Demand ⟂ Need, Satisfaction | Performance, Allocation, Volume)
# (Demand ⟂ Volume | Need, Satisfaction, Type)
# (Demand ⟂ Performance, Satisfaction, Volume | Need, Type, Allocation)
# (Demand ⟂ Performance | Need, Satisfaction, Allocation)
# (Demand ⟂ Performance, Satisfaction | Need, Allocation, Volume)
# (Demand ⟂ Performance, Need, Volume | Allocation, Satisfaction, Type)
# (Demand ⟂ Performance, Need, Satisfaction | Allocation, Type, Volume)
# (Demand ⟂ Performance, Need | Allocation, Satisfaction, Volume)
# (Demand ⟂ Satisfaction, Volume | State, Performance, Need, Type)
# (Demand ⟂ Satisfaction | State, Performance, Need, Volume)
# (Demand ⟂ Satisfaction | State, Performance, Need, Allocation)
# (Demand ⟂ Need, Volume | State, Performance, Satisfaction, Type)
# (Demand ⟂ Need, Satisfaction | State, Performance, Type, Volume)
# (Demand ⟂ Need, Satisfaction, Volume | State, Performance, Allocation, Type)
# (Demand ⟂ Need | State, Performance, Satisfaction, Volume)
# (Demand ⟂ Need | State, Performance, Allocation, Satisfaction)
# (Demand ⟂ Need, Satisfaction | State, Performance, Allocation, Volume)
# (Demand ⟂ Volume | State, Need, Satisfaction, Type)
# (Demand ⟂ Performance, Satisfaction, Volume | State, Need, Type, Allocation)
# (Demand ⟂ Performance | State, Need, Satisfaction, Allocation)
# (Demand ⟂ Performance, Satisfaction | State, Need, Allocation, Volume)
# (Demand ⟂ Performance, Need, Volume | State, Allocation, Satisfaction, Type)
# (Demand ⟂ Performance, Need, Satisfaction | State, Allocation, Type, Volume)
# (Demand ⟂ Performance, Need | State, Allocation, Satisfaction, Volume)
# (Demand ⟂ Volume | Performance, Need, Satisfaction, Type)
# (Demand ⟂ Satisfaction | Performance, Need, Type, Volume)
# (Demand ⟂ Satisfaction, Volume | Performance, Need, Type, Allocation)
# (Demand ⟂ Satisfaction | Performance, Need, Allocation, Volume)
# (Demand ⟂ Need | Performance, Satisfaction, Type, Volume)
# (Demand ⟂ Need, Volume | Performance, Allocation, Satisfaction, Type)
# (Demand ⟂ Need, Satisfaction | Performance, Allocation, Type, Volume)
# (Demand ⟂ Need | Performance, Allocation, Satisfaction, Volume)
# (Demand ⟂ Performance, Volume | Need, Satisfaction, Type, Allocation)
# (Demand ⟂ Performance, Satisfaction | Need, Type, Allocation, Volume)
# (Demand ⟂ Performance | Need, Satisfaction, Allocation, Volume)
# (Demand ⟂ Performance, Need | Allocation, Satisfaction, Type, Volume)
# (Demand ⟂ Volume | Performance, Need, Type, State, Satisfaction)
# (Demand ⟂ Satisfaction | Performance, Need, Type, State, Volume)
# (Demand ⟂ Satisfaction, Volume | Performance, Need, Type, State, Allocation)
# (Demand ⟂ Satisfaction | Performance, Need, State, Volume, Allocation)
# (Demand ⟂ Need | Performance, Type, State, Satisfaction, Volume)
# (Demand ⟂ Need, Volume | Performance, Type, State, Satisfaction, Allocation)
# (Demand ⟂ Need, Satisfaction | Performance, Type, State, Volume, Allocation)
# (Demand ⟂ Need | Performance, State, Satisfaction, Volume, Allocation)
# (Demand ⟂ Performance, Volume | Need, Type, State, Satisfaction, Allocation)
# (Demand ⟂ Performance, Satisfaction | Need, Type, State, Volume, Allocation)
# (Demand ⟂ Performance | Need, State, Satisfaction, Volume, Allocation)
# (Demand ⟂ Performance, Need | Type, State, Satisfaction, Volume, Allocation)
# (Demand ⟂ Volume | Performance, Need, Type, Satisfaction, Allocation)
# (Demand ⟂ Satisfaction | Performance, Need, Type, Volume, Allocation)
# (Demand ⟂ Need | Performance, Type, Satisfaction, Volume, Allocation)
# (Demand ⟂ Performance | Need, Type, Satisfaction, Volume, Allocation)
# (Demand ⟂ Volume | Performance, Need, Type, State, Satisfaction, Allocation)
# (Demand ⟂ Satisfaction | Performance, Need, Type, State, Volume, Allocation)
# (Demand ⟂ Need | Performance, Type, State, Satisfaction, Volume, Allocation)
# (Demand ⟂ Performance | Need, Type, State, Satisfaction, Volume, Allocation)
# (State ⟂ Demand, Type, Volume)
# (State ⟂ Need, Satisfaction | Performance)
# (State ⟂ Demand, Volume | Type)
# (State ⟂ Demand, Type | Volume)
# (State ⟂ Type, Volume | Demand)
# (State ⟂ Performance, Need, Satisfaction | Allocation)
# (State ⟂ Satisfaction | Performance, Need)
# (State ⟂ Need, Satisfaction, Volume | Performance, Type)
# (State ⟂ Need | Performance, Satisfaction)
# (State ⟂ Need, Satisfaction | Performance, Volume)
# (State ⟂ Need, Satisfaction, Type, Volume | Demand, Performance)
# (State ⟂ Need, Satisfaction | Performance, Allocation)
# (State ⟂ Volume | Need, Type)
# (State ⟂ Type, Volume | Demand, Need)
# (State ⟂ Performance, Satisfaction | Need, Allocation)
# (State ⟂ Volume | Satisfaction, Type)
# (State ⟂ Demand | Type, Volume)
# (State ⟂ Volume | Demand, Type)
# (State ⟂ Performance, Need, Satisfaction, Volume | Allocation, Type)
# (State ⟂ Type, Volume | Demand, Satisfaction)
# (State ⟂ Performance, Need | Allocation, Satisfaction)
# (State ⟂ Type | Demand, Volume)
# (State ⟂ Performance, Need, Satisfaction | Allocation, Volume)
# (State ⟂ Performance, Need, Type, Satisfaction, Volume | Demand, Allocation)
# (State ⟂ Satisfaction, Volume | Performance, Need, Type)
# (State ⟂ Satisfaction | Performance, Need, Volume)
# (State ⟂ Volume, Satisfaction, Type | Demand, Performance, Need)
# (State ⟂ Satisfaction | Performance, Need, Allocation)
# (State ⟂ Need, Volume | Performance, Satisfaction, Type)
# (State ⟂ Need, Satisfaction | Performance, Type, Volume)
# (State ⟂ Need, Satisfaction, Volume | Demand, Performance, Type)
# (State ⟂ Need, Satisfaction, Volume | Performance, Allocation, Type)
# (State ⟂ Need | Performance, Satisfaction, Volume)
# (State ⟂ Need, Type, Volume | Demand, Performance, Satisfaction)
# (State ⟂ Need | Performance, Allocation, Satisfaction)
# (State ⟂ Need, Satisfaction, Type | Demand, Performance, Volume)
# (State ⟂ Need, Satisfaction | Performance, Allocation, Volume)
# (State ⟂ Volume, Need, Satisfaction, Type | Demand, Performance, Allocation)
# (State ⟂ Volume | Need, Satisfaction, Type)
# (State ⟂ Volume | Demand, Need, Type)
# (State ⟂ Performance, Satisfaction, Volume | Need, Type, Allocation)
# (State ⟂ Type, Volume | Demand, Need, Satisfaction)
# (State ⟂ Performance | Need, Satisfaction, Allocation)
# (State ⟂ Type | Demand, Need, Volume)
# (State ⟂ Performance, Satisfaction | Need, Allocation, Volume)
# (State ⟂ Volume, Performance, Satisfaction, Type | Demand, Need, Allocation)
# (State ⟂ Volume | Demand, Satisfaction, Type)
# (State ⟂ Performance, Need, Volume | Allocation, Satisfaction, Type)
# (State ⟂ Performance, Need, Satisfaction | Allocation, Type, Volume)
# (State ⟂ Performance, Need, Satisfaction, Volume | Demand, Allocation, Type)
# (State ⟂ Type | Demand, Satisfaction, Volume)
# (State ⟂ Performance, Need | Allocation, Satisfaction, Volume)
# (State ⟂ Performance, Need, Type, Volume | Demand, Allocation, Satisfaction)
# (State ⟂ Performance, Need, Satisfaction, Type | Demand, Allocation, Volume)
# (State ⟂ Volume | Performance, Need, Satisfaction, Type)
# (State ⟂ Satisfaction | Performance, Need, Type, Volume)
# (State ⟂ Satisfaction, Volume | Demand, Performance, Need, Type)
# (State ⟂ Satisfaction, Volume | Performance, Need, Type, Allocation)
# (State ⟂ Type, Volume | Demand, Performance, Need, Satisfaction)
# (State ⟂ Satisfaction, Type | Demand, Performance, Need, Volume)
# (State ⟂ Satisfaction | Performance, Need, Allocation, Volume)
# (State ⟂ Volume, Satisfaction, Type | Demand, Performance, Need, Allocation)
# (State ⟂ Need | Performance, Satisfaction, Type, Volume)
# (State ⟂ Need, Volume | Demand, Performance, Satisfaction, Type)
# (State ⟂ Need, Volume | Performance, Allocation, Satisfaction, Type)
# (State ⟂ Need, Satisfaction | Demand, Performance, Type, Volume)
# (State ⟂ Need, Satisfaction | Performance, Allocation, Type, Volume)
# (State ⟂ Need, Satisfaction, Volume | Demand, Performance, Allocation, Type)
# (State ⟂ Need, Type | Demand, Performance, Satisfaction, Volume)
# (State ⟂ Need | Performance, Allocation, Satisfaction, Volume)
# (State ⟂ Need, Type, Volume | Demand, Performance, Allocation, Satisfaction)
# (State ⟂ Need, Satisfaction, Type | Demand, Performance, Allocation, Volume)
# (State ⟂ Volume | Demand, Need, Satisfaction, Type)
# (State ⟂ Performance, Volume | Need, Satisfaction, Type, Allocation)
# (State ⟂ Performance, Satisfaction | Need, Type, Allocation, Volume)
# (State ⟂ Performance, Satisfaction, Volume | Demand, Need, Type, Allocation)
# (State ⟂ Type | Demand, Need, Satisfaction, Volume)
# (State ⟂ Performance | Need, Satisfaction, Allocation, Volume)
# (State ⟂ Performance, Type, Volume | Demand, Need, Satisfaction, Allocation)
# (State ⟂ Performance, Satisfaction, Type | Demand, Need, Allocation, Volume)
# (State ⟂ Performance, Need | Allocation, Satisfaction, Type, Volume)
# (State ⟂ Performance, Need, Volume | Demand, Allocation, Satisfaction, Type)
# (State ⟂ Performance, Need, Satisfaction | Demand, Allocation, Type, Volume)
# (State ⟂ Performance, Need, Type | Demand, Allocation, Satisfaction, Volume)
# (State ⟂ Volume | Performance, Need, Type, Demand, Satisfaction)
# (State ⟂ Volume | Performance, Need, Type, Satisfaction, Allocation)
# (State ⟂ Satisfaction | Performance, Need, Type, Demand, Volume)
# (State ⟂ Satisfaction | Performance, Need, Type, Volume, Allocation)
# (State ⟂ Satisfaction, Volume | Performance, Need, Type, Demand, Allocation)
# (State ⟂ Type | Performance, Need, Demand, Satisfaction, Volume)
# (State ⟂ Type, Volume | Performance, Need, Demand, Satisfaction, Allocation)
# (State ⟂ Satisfaction, Type | Performance, Need, Demand, Volume, Allocation)
# (State ⟂ Need | Performance, Type, Demand, Satisfaction, Volume)
# (State ⟂ Need | Performance, Type, Satisfaction, Volume, Allocation)
# (State ⟂ Need, Volume | Performance, Type, Demand, Satisfaction, Allocation)
# (State ⟂ Need, Satisfaction | Performance, Type, Demand, Volume, Allocation)
# (State ⟂ Need, Type | Performance, Demand, Satisfaction, Volume, Allocation)
# (State ⟂ Performance | Need, Type, Satisfaction, Volume, Allocation)
# (State ⟂ Performance, Volume | Need, Type, Demand, Satisfaction, Allocation)
# (State ⟂ Performance, Satisfaction | Need, Type, Demand, Volume, Allocation)
# (State ⟂ Performance, Type | Need, Demand, Satisfaction, Volume, Allocation)
# (State ⟂ Performance, Need | Type, Demand, Satisfaction, Volume, Allocation)
# (State ⟂ Volume | Performance, Need, Type, Demand, Satisfaction, Allocation)
# (State ⟂ Satisfaction | Performance, Need, Type, Demand, Volume, Allocation)
# (State ⟂ Type | Performance, Need, Demand, Satisfaction, Volume, Allocation)
# (State ⟂ Need | Performance, Type, Demand, Satisfaction, Volume, Allocation)
# (State ⟂ Performance | Need, Type, Demand, Satisfaction, Volume, Allocation)
# (Satisfaction ⟂ State, Need, Type, Volume, Demand, Allocation | Performance)
# (Satisfaction ⟂ Volume | Type)
# (Satisfaction ⟂ Type, Volume | Demand)
# (Satisfaction ⟂ Demand, Type, State, Volume | Allocation)
# (Satisfaction ⟂ Need, Type, Volume, Demand, Allocation | State, Performance)
# (Satisfaction ⟂ Volume | State, Type)
# (Satisfaction ⟂ Type, Volume | State, Demand)
# (Satisfaction ⟂ Demand, Type, Volume | State, Allocation)
# (Satisfaction ⟂ State, Type, Volume, Demand, Allocation | Performance, Need)
# (Satisfaction ⟂ State, Need, Volume, Demand, Allocation | Performance, Type)
# (Satisfaction ⟂ State, Need, Type, Demand, Allocation | Performance, Volume)
# (Satisfaction ⟂ State, Need, Type, Volume, Allocation | Demand, Performance)
# (Satisfaction ⟂ State, Need, Type, Volume, Demand | Performance, Allocation)
# (Satisfaction ⟂ Volume | Need, Type)
# (Satisfaction ⟂ Type, Volume | Demand, Need)
# (Satisfaction ⟂ Demand, Type, State, Volume | Need, Allocation)
# (Satisfaction ⟂ Volume | Demand, Type)
# (Satisfaction ⟂ Demand, State, Volume | Allocation, Type)
# (Satisfaction ⟂ Type | Demand, Volume)
# (Satisfaction ⟂ Demand, Type, State | Allocation, Volume)
# (Satisfaction ⟂ State, Type, Volume | Demand, Allocation)
# (Satisfaction ⟂ Demand, Allocation, Type, Volume | State, Performance, Need)
# (Satisfaction ⟂ Demand, Need, Allocation, Volume | State, Performance, Type)
# (Satisfaction ⟂ Demand, Need, Type, Allocation | State, Performance, Volume)
# (Satisfaction ⟂ Need, Type, Allocation, Volume | State, Performance, Demand)
# (Satisfaction ⟂ Demand, Need, Type, Volume | State, Performance, Allocation)
# (Satisfaction ⟂ Volume | State, Need, Type)
# (Satisfaction ⟂ Type, Volume | State, Need, Demand)
# (Satisfaction ⟂ Demand, Type, Volume | State, Need, Allocation)
# (Satisfaction ⟂ Volume | State, Type, Demand)
# (Satisfaction ⟂ Demand, Volume | State, Allocation, Type)
# (Satisfaction ⟂ Type | State, Demand, Volume)
# (Satisfaction ⟂ Demand, Type | State, Allocation, Volume)
# (Satisfaction ⟂ Type, Volume | State, Allocation, Demand)
# (Satisfaction ⟂ State, Allocation, Demand, Volume | Performance, Need, Type)
# (Satisfaction ⟂ State, Allocation, Type, Demand | Performance, Need, Volume)
# (Satisfaction ⟂ State, Allocation, Type, Volume | Demand, Performance, Need)
# (Satisfaction ⟂ State, Type, Demand, Volume | Performance, Need, Allocation)
# (Satisfaction ⟂ State, Need, Allocation, Demand | Performance, Type, Volume)
# (Satisfaction ⟂ State, Need, Allocation, Volume | Demand, Performance, Type)
# (Satisfaction ⟂ State, Need, Demand, Volume | Performance, Allocation, Type)
# (Satisfaction ⟂ State, Need, Type, Allocation | Demand, Performance, Volume)
# (Satisfaction ⟂ State, Need, Type, Demand | Performance, Allocation, Volume)
# (Satisfaction ⟂ State, Need, Type, Volume | Demand, Performance, Allocation)
# (Satisfaction ⟂ Volume | Demand, Need, Type)
# (Satisfaction ⟂ State, Demand, Volume | Need, Type, Allocation)
# (Satisfaction ⟂ Type | Demand, Need, Volume)
# (Satisfaction ⟂ State, Type, Demand | Need, Allocation, Volume)
# (Satisfaction ⟂ State, Type, Volume | Demand, Need, Allocation)
# (Satisfaction ⟂ State, Demand | Allocation, Type, Volume)
# (Satisfaction ⟂ State, Volume | Demand, Allocation, Type)
# (Satisfaction ⟂ State, Type | Demand, Allocation, Volume)
# (Satisfaction ⟂ Demand, Allocation, Volume | State, Performance, Need, Type)
# (Satisfaction ⟂ Demand, Allocation, Type | State, Performance, Need, Volume)
# (Satisfaction ⟂ Allocation, Type, Volume | State, Performance, Need, Demand)
# (Satisfaction ⟂ Demand, Type, Volume | State, Performance, Need, Allocation)
# (Satisfaction ⟂ Demand, Need, Allocation | State, Performance, Type, Volume)
# (Satisfaction ⟂ Need, Allocation, Volume | State, Performance, Type, Demand)
# (Satisfaction ⟂ Demand, Need, Volume | State, Performance, Allocation, Type)
# (Satisfaction ⟂ Need, Type, Allocation | State, Performance, Demand, Volume)
# (Satisfaction ⟂ Demand, Need, Type | State, Performance, Allocation, Volume)
# (Satisfaction ⟂ Need, Type, Volume | State, Performance, Allocation, Demand)
# (Satisfaction ⟂ Volume | State, Need, Type, Demand)
# (Satisfaction ⟂ Demand, Volume | State, Need, Type, Allocation)
# (Satisfaction ⟂ Type | State, Need, Demand, Volume)
# (Satisfaction ⟂ Demand, Type | State, Need, Allocation, Volume)
# (Satisfaction ⟂ Type, Volume | State, Allocation, Need, Demand)
# (Satisfaction ⟂ Demand | State, Allocation, Type, Volume)
# (Satisfaction ⟂ Volume | State, Allocation, Type, Demand)
# (Satisfaction ⟂ Type | State, Allocation, Demand, Volume)
# (Satisfaction ⟂ State, Allocation, Demand | Performance, Need, Type, Volume)
# (Satisfaction ⟂ State, Allocation, Volume | Demand, Performance, Need, Type)
# (Satisfaction ⟂ State, Demand, Volume | Performance, Need, Type, Allocation)
# (Satisfaction ⟂ State, Allocation, Type | Demand, Performance, Need, Volume)
# (Satisfaction ⟂ State, Type, Demand | Performance, Need, Allocation, Volume)
# (Satisfaction ⟂ State, Type, Volume | Demand, Performance, Need, Allocation)
# (Satisfaction ⟂ State, Need, Allocation | Demand, Performance, Type, Volume)
# (Satisfaction ⟂ State, Need, Demand | Performance, Allocation, Type, Volume)
# (Satisfaction ⟂ State, Need, Volume | Demand, Performance, Allocation, Type)
# (Satisfaction ⟂ State, Need, Type | Demand, Performance, Allocation, Volume)
# (Satisfaction ⟂ State, Demand | Need, Type, Allocation, Volume)
# (Satisfaction ⟂ State, Volume | Demand, Need, Type, Allocation)
# (Satisfaction ⟂ State, Type | Demand, Need, Allocation, Volume)
# (Satisfaction ⟂ State | Demand, Allocation, Type, Volume)
# (Satisfaction ⟂ Demand, Allocation | Performance, Need, Type, State, Volume)
# (Satisfaction ⟂ Allocation, Volume | Performance, Need, Type, Demand, State)
# (Satisfaction ⟂ Demand, Volume | Performance, Need, Type, State, Allocation)
# (Satisfaction ⟂ Allocation, Type | Performance, Need, Demand, State, Volume)
# (Satisfaction ⟂ Demand, Type | Performance, Need, State, Volume, Allocation)
# (Satisfaction ⟂ Type, Volume | Performance, Need, Demand, State, Allocation)
# (Satisfaction ⟂ Need, Allocation | Performance, Type, Demand, State, Volume)
# (Satisfaction ⟂ Demand, Need | Performance, Type, State, Volume, Allocation)
# (Satisfaction ⟂ Need, Volume | Performance, Type, Demand, State, Allocation)
# (Satisfaction ⟂ Need, Type | Performance, Demand, State, Volume, Allocation)
# (Satisfaction ⟂ Demand | Need, Type, State, Volume, Allocation)
# (Satisfaction ⟂ Volume | Need, Type, Demand, State, Allocation)
# (Satisfaction ⟂ Type | Need, Demand, State, Volume, Allocation)
# (Satisfaction ⟂ State, Allocation | Performance, Need, Type, Demand, Volume)
# (Satisfaction ⟂ State, Demand | Performance, Need, Type, Volume, Allocation)
# (Satisfaction ⟂ State, Volume | Performance, Need, Type, Demand, Allocation)
# (Satisfaction ⟂ State, Type | Performance, Need, Demand, Volume, Allocation)
# (Satisfaction ⟂ State, Need | Performance, Type, Demand, Volume, Allocation)
# (Satisfaction ⟂ State | Need, Type, Demand, Volume, Allocation)
# (Satisfaction ⟂ Allocation | Performance, Need, Type, Demand, State, Volume)
# (Satisfaction ⟂ Demand | Performance, Need, Type, State, Volume, Allocation)
# (Satisfaction ⟂ Volume | Performance, Need, Type, Demand, State, Allocation)
# (Satisfaction ⟂ Type | Performance, Need, Demand, State, Volume, Allocation)
# (Satisfaction ⟂ Need | Performance, Type, Demand, State, Volume, Allocation)
# (Satisfaction ⟂ State | Performance, Need, Type, Demand, Volume, Allocation)
# (Volume ⟂ State)
# (Volume ⟂ Need, Satisfaction | Performance)
# (Volume ⟂ State, Performance, Need, Satisfaction, Demand, Allocation | Type)
# (Volume ⟂ State, Performance, Need, Satisfaction, Allocation | Demand)
# (Volume ⟂ Performance, Need, Satisfaction | Allocation)
# (Volume ⟂ Need, Satisfaction | State, Performance)
# (Volume ⟂ Performance, Need, Satisfaction, Demand, Allocation | State, Type)
# (Volume ⟂ Performance, Need, Satisfaction, Allocation | State, Demand)
# (Volume ⟂ Performance, Need, Satisfaction | State, Allocation)
# (Volume ⟂ Satisfaction | Performance, Need)
# (Volume ⟂ State, Need, Satisfaction, Demand, Allocation | Performance, Type)
# (Volume ⟂ Need | Performance, Satisfaction)
# (Volume ⟂ State, Need, Satisfaction, Allocation | Demand, Performance)
# (Volume ⟂ Need, Satisfaction | Performance, Allocation)
# (Volume ⟂ State, Performance, Satisfaction, Demand, Allocation | Need, Type)
# (Volume ⟂ State, Performance, Allocation, Satisfaction | Demand, Need)
# (Volume ⟂ Performance, Satisfaction | Need, Allocation)
# (Volume ⟂ State, Performance, Need, Demand, Allocation | Satisfaction, Type)
# (Volume ⟂ State, Performance, Need, Satisfaction, Allocation | Demand, Type)
# (Volume ⟂ State, Performance, Need, Satisfaction, Demand | Allocation, Type)
# (Volume ⟂ State, Performance, Need, Allocation | Demand, Satisfaction)
# (Volume ⟂ Performance, Need | Allocation, Satisfaction)
# (Volume ⟂ State, Performance, Need, Satisfaction | Demand, Allocation)
# (Volume ⟂ Satisfaction | State, Performance, Need)
# (Volume ⟂ Demand, Need, Satisfaction, Allocation | State, Performance, Type)
# (Volume ⟂ Need | State, Performance, Satisfaction)
# (Volume ⟂ Need, Satisfaction, Allocation | State, Performance, Demand)
# (Volume ⟂ Need, Satisfaction | State, Performance, Allocation)
# (Volume ⟂ Demand, Performance, Allocation, Satisfaction | State, Need, Type)
# (Volume ⟂ Performance, Allocation, Satisfaction | State, Need, Demand)
# (Volume ⟂ Performance, Satisfaction | State, Need, Allocation)
# (Volume ⟂ Demand, Performance, Need, Allocation | State, Satisfaction, Type)
# (Volume ⟂ Performance, Need, Satisfaction, Allocation | State, Type, Demand)
# (Volume ⟂ Demand, Performance, Need, Satisfaction | State, Allocation, Type)
# (Volume ⟂ Performance, Need, Allocation | State, Satisfaction, Demand)
# (Volume ⟂ Performance, Need | State, Allocation, Satisfaction)
# (Volume ⟂ Performance, Need, Satisfaction | State, Allocation, Demand)
# (Volume ⟂ State, Allocation, Satisfaction, Demand | Performance, Need, Type)
# (Volume ⟂ State, Allocation, Satisfaction | Demand, Performance, Need)
# (Volume ⟂ Satisfaction | Performance, Need, Allocation)
# (Volume ⟂ State, Need, Allocation, Demand | Performance, Satisfaction, Type)
# (Volume ⟂ State, Need, Satisfaction, Allocation | Demand, Performance, Type)
# (Volume ⟂ State, Need, Satisfaction, Demand | Performance, Allocation, Type)
# (Volume ⟂ State, Need, Allocation | Demand, Performance, Satisfaction)
# (Volume ⟂ Need | Performance, Allocation, Satisfaction)
# (Volume ⟂ State, Need, Satisfaction | Demand, Performance, Allocation)
# (Volume ⟂ State, Performance, Allocation, Demand | Need, Satisfaction, Type)
# (Volume ⟂ State, Performance, Allocation, Satisfaction | Demand, Need, Type)
# (Volume ⟂ State, Performance, Satisfaction, Demand | Need, Type, Allocation)
# (Volume ⟂ State, Performance, Allocation | Demand, Need, Satisfaction)
# (Volume ⟂ Performance | Need, Satisfaction, Allocation)
# (Volume ⟂ State, Performance, Satisfaction | Demand, Need, Allocation)
# (Volume ⟂ State, Performance, Need, Allocation | Demand, Satisfaction, Type)
# (Volume ⟂ State, Performance, Need, Demand | Allocation, Satisfaction, Type)
# (Volume ⟂ State, Performance, Need, Satisfaction | Demand, Allocation, Type)
# (Volume ⟂ State, Performance, Need | Demand, Allocation, Satisfaction)
# (Volume ⟂ Demand, Allocation, Satisfaction | State, Performance, Need, Type)
# (Volume ⟂ Allocation, Satisfaction | State, Performance, Need, Demand)
# (Volume ⟂ Satisfaction | State, Performance, Need, Allocation)
# (Volume ⟂ Demand, Need, Allocation | State, Performance, Satisfaction, Type)
# (Volume ⟂ Need, Satisfaction, Allocation | State, Performance, Type, Demand)
# (Volume ⟂ Demand, Need, Satisfaction | State, Performance, Allocation, Type)
# (Volume ⟂ Need, Allocation | State, Performance, Satisfaction, Demand)
# (Volume ⟂ Need | State, Performance, Allocation, Satisfaction)
# (Volume ⟂ Need, Satisfaction | State, Performance, Allocation, Demand)
# (Volume ⟂ Demand, Performance, Allocation | State, Need, Satisfaction, Type)
# (Volume ⟂ Performance, Allocation, Satisfaction | State, Need, Type, Demand)
# (Volume ⟂ Demand, Performance, Satisfaction | State, Need, Type, Allocation)
# (Volume ⟂ Performance, Allocation | State, Need, Satisfaction, Demand)
# (Volume ⟂ Performance | State, Need, Satisfaction, Allocation)
# (Volume ⟂ Performance, Satisfaction | State, Allocation, Need, Demand)
# (Volume ⟂ Performance, Need, Allocation | State, Satisfaction, Type, Demand)
# (Volume ⟂ Demand, Performance, Need | State, Allocation, Satisfaction, Type)
# (Volume ⟂ Performance, Need, Satisfaction | State, Allocation, Type, Demand)
# (Volume ⟂ Performance, Need | State, Allocation, Satisfaction, Demand)
# (Volume ⟂ State, Allocation, Demand | Performance, Need, Satisfaction, Type)
# (Volume ⟂ State, Allocation, Satisfaction | Demand, Performance, Need, Type)
# (Volume ⟂ State, Satisfaction, Demand | Performance, Need, Type, Allocation)
# (Volume ⟂ State, Allocation | Demand, Performance, Need, Satisfaction)
# (Volume ⟂ State, Satisfaction | Demand, Performance, Need, Allocation)
# (Volume ⟂ State, Need, Allocation | Demand, Performance, Satisfaction, Type)
# (Volume ⟂ State, Need, Demand | Performance, Allocation, Satisfaction, Type)
# (Volume ⟂ State, Need, Satisfaction | Demand, Performance, Allocation, Type)
# (Volume ⟂ State, Need | Demand, Performance, Allocation, Satisfaction)
# (Volume ⟂ State, Performance, Allocation | Demand, Need, Satisfaction, Type)
# (Volume ⟂ State, Performance, Demand | Need, Satisfaction, Type, Allocation)
# (Volume ⟂ State, Performance, Satisfaction | Demand, Need, Type, Allocation)
# (Volume ⟂ State, Performance | Demand, Need, Satisfaction, Allocation)
# (Volume ⟂ State, Performance, Need | Demand, Allocation, Satisfaction, Type)
# (Volume ⟂ Demand, Allocation | Performance, Need, Type, State, Satisfaction)
# (Volume ⟂ Allocation, Satisfaction | Performance, Need, Type, Demand, State)
# (Volume ⟂ Demand, Satisfaction | Performance, Need, Type, State, Allocation)
# (Volume ⟂ Allocation | Performance, Need, Demand, State, Satisfaction)
# (Volume ⟂ Satisfaction | Performance, Need, Demand, State, Allocation)
# (Volume ⟂ Need, Allocation | Performance, Type, Demand, State, Satisfaction)
# (Volume ⟂ Demand, Need | Performance, Type, State, Satisfaction, Allocation)
# (Volume ⟂ Need, Satisfaction | Performance, Type, Demand, State, Allocation)
# (Volume ⟂ Need | Performance, Demand, State, Satisfaction, Allocation)
# (Volume ⟂ Performance, Allocation | Need, Type, Demand, State, Satisfaction)
# (Volume ⟂ Demand, Performance | Need, Type, State, Satisfaction, Allocation)
# (Volume ⟂ Performance, Satisfaction | Need, Type, Demand, State, Allocation)
# (Volume ⟂ Performance | Need, Demand, State, Satisfaction, Allocation)
# (Volume ⟂ Performance, Need | Type, Demand, State, Satisfaction, Allocation)
# (Volume ⟂ State, Allocation | Performance, Need, Type, Demand, Satisfaction)
# (Volume ⟂ State, Demand | Performance, Need, Type, Satisfaction, Allocation)
# (Volume ⟂ State, Satisfaction | Performance, Need, Type, Demand, Allocation)
# (Volume ⟂ State | Performance, Need, Demand, Satisfaction, Allocation)
# (Volume ⟂ State, Need | Performance, Type, Demand, Satisfaction, Allocation)
# (Volume ⟂ State, Performance | Need, Type, Demand, Satisfaction, Allocation)
# (Volume ⟂ Allocation | Performance, Need, Type, Demand, State, Satisfaction)
# (Volume ⟂ Demand | Performance, Need, Type, State, Satisfaction, Allocation)
# (Volume ⟂ Satisfaction | Performance, Need, Type, Demand, State, Allocation)
# (Volume ⟂ Need | Performance, Type, Demand, State, Satisfaction, Allocation)
# (Volume ⟂ Performance | Need, Type, Demand, State, Satisfaction, Allocation)
# (Volume ⟂ State | Performance, Need, Type, Demand, Satisfaction, Allocation)
# (Allocation ⟂ Need, Satisfaction | Performance)
# (Allocation ⟂ Volume | Type)
# (Allocation ⟂ Type, Volume | Demand)
# (Allocation ⟂ Need, Satisfaction | State, Performance)
# (Allocation ⟂ Volume | State, Type)
# (Allocation ⟂ Type, Volume | State, Demand)
# (Allocation ⟂ Satisfaction | Performance, Need)
# (Allocation ⟂ Need, Satisfaction, Volume | Performance, Type)
# (Allocation ⟂ Need | Performance, Satisfaction)
# (Allocation ⟂ Need, Satisfaction | Performance, Volume)
# (Allocation ⟂ Need, Satisfaction, Type, Volume | Demand, Performance)
# (Allocation ⟂ Volume | Need, Type)
# (Allocation ⟂ Type, Volume | Demand, Need)
# (Allocation ⟂ Volume | Satisfaction, Type)
# (Allocation ⟂ Volume | Demand, Type)
# (Allocation ⟂ Type, Volume | Demand, Satisfaction)
# (Allocation ⟂ Type | Demand, Volume)
# (Allocation ⟂ Satisfaction | State, Performance, Need)
# (Allocation ⟂ Need, Satisfaction, Volume | State, Performance, Type)
# (Allocation ⟂ Need | State, Performance, Satisfaction)
# (Allocation ⟂ Need, Satisfaction | State, Performance, Volume)
# (Allocation ⟂ Volume, Need, Satisfaction, Type | State, Performance, Demand)
# (Allocation ⟂ Volume | State, Need, Type)
# (Allocation ⟂ Type, Volume | State, Need, Demand)
# (Allocation ⟂ Volume | State, Satisfaction, Type)
# (Allocation ⟂ Volume | State, Type, Demand)
# (Allocation ⟂ Type, Volume | State, Satisfaction, Demand)
# (Allocation ⟂ Type | State, Demand, Volume)
# (Allocation ⟂ Satisfaction, Volume | Performance, Need, Type)
# (Allocation ⟂ Satisfaction | Performance, Need, Volume)
# (Allocation ⟂ Volume, Satisfaction, Type | Demand, Performance, Need)
# (Allocation ⟂ Need, Volume | Performance, Satisfaction, Type)
# (Allocation ⟂ Need, Satisfaction | Performance, Type, Volume)
# (Allocation ⟂ Need, Satisfaction, Volume | Demand, Performance, Type)
# (Allocation ⟂ Need | Performance, Satisfaction, Volume)
# (Allocation ⟂ Need, Type, Volume | Demand, Performance, Satisfaction)
# (Allocation ⟂ Need, Satisfaction, Type | Demand, Performance, Volume)
# (Allocation ⟂ Volume | Need, Satisfaction, Type)
# (Allocation ⟂ Volume | Demand, Need, Type)
# (Allocation ⟂ Type, Volume | Demand, Need, Satisfaction)
# (Allocation ⟂ Type | Demand, Need, Volume)
# (Allocation ⟂ Volume | Demand, Satisfaction, Type)
# (Allocation ⟂ Type | Demand, Satisfaction, Volume)
# (Allocation ⟂ Satisfaction, Volume | State, Performance, Need, Type)
# (Allocation ⟂ Satisfaction | State, Performance, Need, Volume)
# (Allocation ⟂ Volume, Satisfaction, Type | State, Performance, Need, Demand)
# (Allocation ⟂ Need, Volume | State, Performance, Satisfaction, Type)
# (Allocation ⟂ Need, Satisfaction | State, Performance, Type, Volume)
# (Allocation ⟂ Need, Satisfaction, Volume | State, Performance, Type, Demand)
# (Allocation ⟂ Need | State, Performance, Satisfaction, Volume)
# (Allocation ⟂ Need, Type, Volume | State, Performance, Satisfaction, Demand)
# (Allocation ⟂ Need, Satisfaction, Type | State, Performance, Demand, Volume)
# (Allocation ⟂ Volume | State, Need, Satisfaction, Type)
# (Allocation ⟂ Volume | State, Need, Type, Demand)
# (Allocation ⟂ Type, Volume | State, Need, Satisfaction, Demand)
# (Allocation ⟂ Type | State, Need, Demand, Volume)
# (Allocation ⟂ Volume | State, Satisfaction, Type, Demand)
# (Allocation ⟂ Type | State, Satisfaction, Demand, Volume)
# (Allocation ⟂ Volume | Performance, Need, Satisfaction, Type)
# (Allocation ⟂ Satisfaction | Performance, Need, Type, Volume)
# (Allocation ⟂ Satisfaction, Volume | Demand, Performance, Need, Type)
# (Allocation ⟂ Type, Volume | Demand, Performance, Need, Satisfaction)
# (Allocation ⟂ Satisfaction, Type | Demand, Performance, Need, Volume)
# (Allocation ⟂ Need | Performance, Satisfaction, Type, Volume)
# (Allocation ⟂ Need, Volume | Demand, Performance, Satisfaction, Type)
# (Allocation ⟂ Need, Satisfaction | Demand, Performance, Type, Volume)
# (Allocation ⟂ Need, Type | Demand, Performance, Satisfaction, Volume)
# (Allocation ⟂ Volume | Demand, Need, Satisfaction, Type)
# (Allocation ⟂ Type | Demand, Need, Satisfaction, Volume)
# (Allocation ⟂ Volume | Performance, Need, Type, State, Satisfaction)
# (Allocation ⟂ Satisfaction | Performance, Need, Type, State, Volume)
# (Allocation ⟂ Satisfaction, Volume | Performance, Need, Type, Demand, State)
# (Allocation ⟂ Type, Volume | Performance, Need, Demand, State, Satisfaction)
# (Allocation ⟂ Satisfaction, Type | Performance, Need, Demand, State, Volume)
# (Allocation ⟂ Need | Performance, Type, State, Satisfaction, Volume)
# (Allocation ⟂ Need, Volume | Performance, Type, Demand, State, Satisfaction)
# (Allocation ⟂ Need, Satisfaction | Performance, Type, Demand, State, Volume)
# (Allocation ⟂ Need, Type | Performance, Demand, State, Satisfaction, Volume)
# (Allocation ⟂ Volume | Need, Type, Demand, State, Satisfaction)
# (Allocation ⟂ Type | Need, Demand, State, Satisfaction, Volume)
# (Allocation ⟂ Volume | Performance, Need, Type, Demand, Satisfaction)
# (Allocation ⟂ Satisfaction | Performance, Need, Type, Demand, Volume)
# (Allocation ⟂ Type | Performance, Need, Demand, Satisfaction, Volume)
# (Allocation ⟂ Need | Performance, Type, Demand, Satisfaction, Volume)
# (Allocation ⟂ Volume | Performance, Need, Type, Demand, State, Satisfaction)
# (Allocation ⟂ Satisfaction | Performance, Need, Type, Demand, State, Volume)
# (Allocation ⟂ Type | Performance, Need, Demand, State, Satisfaction, Volume)
# (Allocation ⟂ Need | Performance, Type, Demand, State, Satisfaction, Volume)

# %%
from pgmpy.inference import VariableElimination

# Calculate existing probabilities to verify that everything is correct
inference = VariableElimination(model)
prob_Performance = inference.query(variables=['Performance'])
print(prob_Performance)
# Out:
# +----------------+--------------------+
# | Performance    |   phi(Performance) |
# +================+====================+
# | Performance(0) |             0.1800 |
# +----------------+--------------------+
# | Performance(1) |             0.8200 |
# +----------------+--------------------+

# %%
# Perform another probability calculation
prob_Allocation = inference.query(variables=['Allocation'])
print(prob_Allocation)
# Out:
# +---------------+-------------------+
# | Allocation    |   phi(Allocation) |
# +===============+===================+
# | Allocation(0) |            0.8000 |
# +---------------+-------------------+
# | Allocation(1) |            0.2000 |
# +---------------+-------------------+

# %%
# Probability of having storage allocation given that the resource state is not free
proba_allocation_state = inference.query(variables=['Allocation'], evidence= {'State':1}) 
print(proba_allocation_state)
# Out:
# +---------------+-------------------+
# | Allocation    |   phi(Allocation) |
# +===============+===================+
# | Allocation(0) |            0.8000 |
# +---------------+-------------------+
# | Allocation(1) |            0.2000 |
# +---------------+-------------------+

# %%
# Probability of performance given that allocation is high
proba_allocation_state_demand = inference.query(variables=['Performance'], evidence= {'Allocation':1}) 
print(proba_allocation_state_demand)
# Out:
# +----------------+--------------------+
# | Performance    |   phi(Performance) |
# +================+====================+
# | Performance(0) |             0.1000 |
# +----------------+--------------------+
# | Performance(1) |             0.9000 |
# +----------------+--------------------+
